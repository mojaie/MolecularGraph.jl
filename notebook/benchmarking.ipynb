# %%
import Pkg
Pkg.activate("..")
using Profile
using MolecularGraph
# Out:
# ┌ Info: Recompiling stale cache file /Users/smatsuoka/.julia/compiled/v1.1/MolecularGraph/6vz1i.ji for MolecularGraph [6c89ec66-9cd8-5372-9f91-fabc50dd27fd]
# └ @ Base loading.jl:1184
# loading: funcgroup.yaml
# loading: ring.yaml
# loading: biomolecule.yaml

# %%
# path =  joinpath(dirname(@__FILE__), "..", "_resources", "open structures.sdf")
path =  joinpath(dirname(@__FILE__), "..", "_resources", "DrugBank_FDA_Approved.sdf")

function loadsdf()
    for (i, m) in enumerate(sdfilereader(open(path)))
        drawsvg(m, 400, 400)
    end
    println("ok")
    return
end
# Out:
# loadsdf (generic function with 1 method)

# %%
@profile loadsdf()
# Profile.print()
Profile.print(format=:flat)

# loadsdf()
# Out:
# ok
# ┌ Warning: The profile data buffer is full; profiling probably terminated
# │ before your program finished. To profile for longer runs, call
# │ `Profile.init()` with a larger buffer and/or larger delay.
# └ @ Profile /Users/osx/buildbot/slave/package_osx64/build/usr/share/julia/stdlib/v1.1/Profile/src/Profile.jl:312
#  Count File                        Line Function
#   1406 ./In[2]                        5 loadsdf()
#   8108 ./In[2]                        6 loadsdf()
#    127 ./abstractarray.jl          1511 #cat#104
#     94 ./abstractarray.jl          1384 #cat_t#103(::Int64, ::Function, ::Ty...
#      1 ./abstractarray.jl          1396 __cat(::Array{Int64,1}, ::Tuple{Int6...
#      1 ./abstractarray.jl          1397 __cat(::Array{Int64,1}, ::Tuple{Int6...
#      3 ./abstractarray.jl          1387 _cat_t(::Int64, ::Type, ::Array{Int6...
#     16 ./abstractarray.jl          1388 _cat_t(::Int64, ::Type, ::Array{Int6...
#     51 ./abstractarray.jl          1392 _cat_t(::Int64, ::Type, ::Array{Int6...
#      3 ./abstractarray.jl           946 _getindex
#      1 ./abstractarray.jl          1308 _typed_vcat(::Type{Float64}, ::Tuple...
#      4 ./abstractarray.jl            75 axes
#      5 ./abstractarray.jl            93 axes1
#     10 ./abstractarray.jl          1339 cat_similar(::Array{Int64,1}, ::Type...
#      1 ./abstractarray.jl           434 checkbounds
#      1 ./abstractarray.jl           449 checkbounds
#      2 ./abstractarray.jl           845 copymutable
#      2 ./abstractarray.jl           668 copyto!(::Array{Any,1}, ::Tuple{Symb...
#      1 ./abstractarray.jl           672 copyto!(::Array{Any,1}, ::Tuple{Symb...
#      2 ./abstractarray.jl           745 copyto!
#      2 ./abstractarray.jl           753 copyto!(::Core.Compiler.IndexLinear,...
#      5 ./abstractarray.jl           214 eachindex
#      2 ./abstractarray.jl           635 empty
#    134 ./abstractarray.jl          1866 foreach
#      2 ./abstractarray.jl          1866 foreach(::getfield(Core.Compiler, Sy...
#     29 ./abstractarray.jl          1866 foreach
#     17 ./abstractarray.jl          1866 foreach(::getfield(Core.Compiler, Sy...
#      1 ./abstractarray.jl          1866 foreach
#     13 ./abstractarray.jl           927 getindex
#      1 ./abstractarray.jl          1226 hcat
#     67 ./abstractarray.jl          1661 hvcat
#    250 ./abstractarray.jl          1662 hvcat
#      4 ./abstractarray.jl          1654 hvcat_fill(::Array{Float64,2}, ::Tup...
#      1 ./abstractarray.jl           863 isempty
#      4 ./abstractarray.jl           249 lastindex
#     17 ./abstractarray.jl          2018 map
#      1 ./abstractarray.jl          2011 map!(::getfield(Core.Compiler, Symbo...
#      1 ./abstractarray.jl          2012 map!(::getfield(Core.Compiler, Symbo...
#      2 ./abstractarray.jl          2095 push!
#      5 ./abstractarray.jl           575 similar
#      1 ./abstractarray.jl           581 similar
#      3 ./abstractarray.jl           583 similar
#     23 ./abstractarray.jl           617 similar
#      2 ./abstractarray.jl           617 similar(::Type{Array{Any,N} where N}...
#    120 ./abstractarray.jl           617 similar
#    145 ./abstractarray.jl           618 similar
#     37 ./abstractarray.jl          1676 typed_hvcat(::Type{Float64}, ::Tuple...
#      4 ./abstractarray.jl          1680 typed_hvcat(::Type{Float64}, ::Tuple...
#     72 ./abstractarray.jl          1684 typed_hvcat(::Type{Float64}, ::Tuple...
#    121 ./abstractarray.jl          1687 typed_hvcat(::Type{Float64}, ::Tuple...
#      1 ./abstractarray.jl          1319 typed_vcat(::Type{Float64}, ::Linear...
#      1 ./abstractarray.jl          1319 typed_vcat
#      2 ./abstractdict.jl             40 Type
#     52 ./abstractdict.jl            509 Type
#      4 ./abstractdict.jl            512 Core.Compiler.IdDict{Int64,Int64}(::...
#      3 ./abstractdict.jl            513 Core.Compiler.IdDict{Any,Any}(::Core...
#     11 ./abstractdict.jl            675 Type
#     11 ./abstractdict.jl            487 convert
#      8 ./abstractdict.jl            538 dict_with_eltype
#      8 ./abstractdict.jl            545 dict_with_eltype
#     11 ./abstractdict.jl            594 get
#      1 ./abstractdict.jl            595 get
#      3 ./abstractdict.jl            598 getindex
#      7 ./abstractdict.jl             17 haskey
#      9 ./abstractdict.jl            665 in
#      2 ./abstractdict.jl            687 in
#      1 ./abstractdict.jl             98 keys
#      1 ./abstractdict.jl             54 length
#     13 ./abstractdict.jl            178 merge!(::Dict{String,Any}, ::Dict{An...
#      1 ./abstractdict.jl            688 push!
#      5 ./abstractdict.jl            588 setindex!
#      6 ./abstractset.jl             340 mapfilter(::getfield(Core.Compiler, ...
#      2 ./abstractset.jl             145 setdiff
#      2 ./abstractset.jl              79 union!(::Set{Int64}, ::Base.KeySet{I...
#      6 ./abstractset.jl              80 union!(::Set{Int64}, ::Base.KeySet{I...
#     11 ./abstractset.jl              81 union!(::Set{Int64}, ::Base.KeySet{I...
#      9 ./abstractset.jl              82 union!(::Set{Int64}, ::Base.KeySet{I...
#      1 ./array.jl                   308 Type
#      5 ./array.jl                  1022 Type
#      1 ./array.jl                   908 _append!(::Array{Int64,1}, ::Core.Co...
#      1 ./array.jl                   597 _array_for
#      8 ./array.jl                   505 _collect
#      2 ./array.jl                   506 _collect
#      3 ./array.jl                   508 _collect(::Type{Int64}, ::Core.Compi...
#      2 ./array.jl                   509 _collect(::Type{Int64}, ::Core.Compi...
#      3 ./array.jl                   510 _collect(::Type{Int64}, ::Core.Compi...
#      4 ./array.jl                   550 _collect(::Core.Compiler.UnitRange{I...
#      1 ./array.jl                   554 _collect(::Core.Compiler.UnitRange{I...
#      2 ./array.jl                   556 _collect(::Core.Compiler.UnitRange{I...
#     16 ./array.jl                   619 _collect(::Array{Core.Compiler.Basic...
#      1 ./array.jl                   624 _collect(::Array{Core.Compiler.Basic...
#      4 ./array.jl                   562 _collect_indices
#      2 ./array.jl                   819 _deletebeg!
#      3 ./array.jl                   821 _deleteend!
#      1 ./array.jl                  2107 _findmin(::Array{Any,1}, ::Colon)
#      3 ./array.jl                  2109 _findmin(::Array{Any,1}, ::Colon)
#      2 ./array.jl                   810 _growbeg!
#    126 ./array.jl                   812 _growend!
#      4 ./array.jl                   767 _setindex!
#      1 ./array.jl                   516 _similar_for
#      2 ./array.jl                   517 _similar_for
#      1 ./array.jl                   519 _similar_for
#      1 ./array.jl                   900 append!
#      4 ./array.jl                   503 collect
#      1 ./array.jl                   503 collect(::Type{Core.LineInfoNode}, :...
#      4 ./array.jl                   503 collect
#      2 ./array.jl                   503 collect(::Type{Core.LineInfoNode}, :...
#      8 ./array.jl                   503 collect
#      4 ./array.jl                   503 collect(::Type{Core.LineInfoNode}, :...
#      5 ./array.jl                   544 collect(::Core.Compiler.Iterators.Fi...
#      4 ./array.jl                   544 collect
#      4 ./array.jl                   546 collect
#     12 ./array.jl                   606 collect(::Base.Generator{UnitRange{I...
#     27 ./array.jl                   611 collect(::Base.Generator{Set{Int64},...
#     17 ./array.jl                   548 collect_similar
#      2 ./array.jl                   651 collect_to!
#      2 ./array.jl                   630 collect_to_with_first!(::Array{SDFil...
#      5 ./array.jl                   308 copy
#      1 ./array.jl                   308 copy(::Array{Any,1})
#      4 ./array.jl                   308 copy
#      2 ./array.jl                   308 copy(::Array{Int32,1})
#      1 ./array.jl                   308 copy
#      3 ./array.jl                   308 copy(::Array{Any,1})
#      7 ./array.jl                   308 copy
#      1 ./array.jl                   308 copy(::Array{Any,1})
#      1 ./array.jl                   308 copy
#     10 ./array.jl                   401 fill
#      1 ./array.jl                   401 fill(::Bool, ::Int64)
#      6 ./array.jl                   401 fill
#      1 ./array.jl                   401 fill(::Bool, ::Int64)
#     25 ./array.jl                   401 fill
#     43 ./array.jl                   403 fill
#      2 ./array.jl                   372 fill!(::Array{Int64,1}, ::Int64)
#      1 ./array.jl                   373 fill!(::Array{Int64,1}, ::Int64)
#      7 ./array.jl                  2351 filter
#      2 ./array.jl                  1741 findfirst
#    120 ./array.jl                   350 getindex
#     98 ./array.jl                   351 getindex
#      1 ./array.jl                   353 getindex
#      7 ./array.jl                   356 getindex(::Type{Any}, ::Any, ::Any, ...
#      1 ./array.jl                   362 getindex(::Type{Any})
#      7 ./array.jl                   362 getindex
#      7 ./array.jl                   362 getindex(::Type{Any})
#      4 ./array.jl                   362 getindex
#      3 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Any,1}, ::Int64)
#      2 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Int64,1}, ::Int64)
#     21 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Core.Compiler.Basic...
#      8 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Any,1}, ::Int64)
#      7 ./array.jl                   729 getindex
#      2 ./array.jl                   729 getindex(::Array{Any,1}, ::Int64)
#     35 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Array{Int64,1},1}, ...
#     14 ./array.jl                   729 getindex
#      1 ./array.jl                   729 getindex(::Array{Core.Compiler.Lifte...
#     22 ./array.jl                   729 getindex
#      2 ./array.jl                   730 getindex
#      1 ./array.jl                   735 getindex
#      9 ./array.jl                   737 getindex
#      1 ./array.jl                   737 getindex(::Array{Any,1}, ::Core.Comp...
#      1 ./array.jl                   729 indexed_iterate
#      1 ./array.jl                   207 isassigned
#     12 ./array.jl                   705 iterate
#      1 ./array.jl                   705 iterate(::Array{Array{Int64,1},1}, :...
#     14 ./array.jl                   705 iterate
#     31 ./array.jl                   705 iterate(::Array{Any,1})
#    188 ./array.jl                   705 iterate
#      1 ./array.jl                   705 iterate(::Array{Any,1}, ::Int64)
#     30 ./array.jl                   705 iterate
#    180 ./array.jl                   199 length
#      1 ./array.jl                   729 pop!
#      3 ./array.jl                  1065 pop!
#      2 ./array.jl                  1066 pop!
#      1 ./array.jl                  1126 popfirst!
#      2 ./array.jl                  1127 popfirst!
#      1 ./array.jl                   199 push!
#      3 ./array.jl                   767 push!
#      3 ./array.jl                   853 push!
#      1 ./array.jl                   853 push!(::Array{String,1}, ::SubString...
#     17 ./array.jl                   854 push!
#      2 ./array.jl                   854 push!(::Array{Bool,1}, ::Bool)
#     42 ./array.jl                   854 push!
#     10 ./array.jl                   854 push!(::Array{Int64,1}, ::Int64)
#     10 ./array.jl                   854 push!
#      3 ./array.jl                   855 push!
#      5 ./array.jl                   860 push!
#      1 ./array.jl                   860 push!(::Array{Any,1}, ::Any)
#      2 ./array.jl                   860 push!
#      1 ./array.jl                   861 push!
#      2 ./array.jl                  1089 pushfirst!
#      1 ./array.jl                  1002 resize!
#     14 ./array.jl                  1004 resize!
#      2 ./array.jl                  1009 resize!
#     18 ./array.jl                   767 setindex!
#      2 ./array.jl                   312 similar
#     11 ./array.jl                   316 similar
#      5 ./array.jl                   317 similar(::Array{Int64,1}, ::Type, ::...
#      3 ./array.jl                   317 similar
#      2 ./array.jl                   705 simple_dce!(::Core.Compiler.Incremen...
#      2 ./array.jl                   155 size
#     23 ./array.jl                  1022 sizehint!
#      2 ./array.jl                   199 skip_deleted
#      1 ./array.jl                   729 unsafe_bitgetindex
#      8 ./array.jl                   129 vect
#      1 ./array.jl                   130 vect
#     11 ./array.jl                   148 vect(::String, ::Vararg{Any,N} where N)
#     17 ./array.jl                   151 vect(::Symbol, ::Vararg{Any,N} where N)
#      1 ./array.jl                   151 vect
#     27 ./array.jl                   151 vect(::Int64, ::Vararg{Any,N} where N)
#     17 ./array.jl                   151 vect
#      1 ./array.jl                   199 zeros
#     46 ./array.jl                   449 zeros
#     45 ./array.jl                   452 zeros
#      1 ./arraymath.jl                39 #draw2d!#58(::Dict{Symbol,Any}, ::Bo...
#      2 ./arraymath.jl                47 +(::Array{Float64,2}, ::Array{Float6...
#      3 ./arraymath.jl                47 +
#      1 ./arraymath.jl                39 -
#      1 ./arraymath.jl                55 /
#      1 ./bitarray.jl                 24 Core.Compiler.BitArray{1}(::UndefIni...
#      6 ./bitarray.jl                 32 Core.Compiler.BitArray{1}(::UndefIni...
#      8 ./bitarray.jl                 66 Type
#      1 ./bitarray.jl                655 _unsafe_bitsetindex!
#      8 ./bitarray.jl                376 falses
#      8 ./bitarray.jl                378 falses
#      3 ./bitarray.jl               1592 findall(::BitArray{1})
#      1 ./bitarray.jl                641 getindex
#      1 ./bitarray.jl               1366 unsafe_bitfindnext(::Array{UInt64,1}...
#      1 ./bitarray.jl               1372 unsafe_bitfindnext(::Array{UInt64,1}...
#      1 ./bitset.jl                  101 <
#     47 ./bitset.jl                   18 Type
#      5 ./bitset.jl                   29 Type
#      4 ./bitset.jl                   69 _bits_findnext
#      1 ./bitset.jl                  377 _check0
#      5 ./bitset.jl                  113 _growend0!
#      1 ./bitset.jl                  114 _growend0!
#      2 ./bitset.jl                  115 _growend0!
#      1 ./bitset.jl                  186 _matched_map!
#      1 ./bitset.jl                  196 _matched_map!(::getfield(Core.Compil...
#      1 ./bitset.jl                   84 _setint!
#      1 ./bitset.jl                   86 _setint!
#      8 ./bitset.jl                   97 _setint!
#      1 ./bitset.jl                  104 _setint!
#      1 ./bitset.jl                  308 call_result_unused
#      1 ./bitset.jl                   18 construct_ssa!(::Core.CodeInfo, ::Ar...
#      1 ./bitset.jl                   46 copy(::Core.Compiler.BitSet)
#      1 ./bitset.jl                   47 copymutable
#      2 ./bitset.jl                  297 delete!
#      1 ./bitset.jl                   86 idf(::Core.Compiler.CFG, ::Core.Comp...
#      2 ./bitset.jl                  308 isempty
#      4 ./bitset.jl                  344 iterate
#      1 ./bitset.jl                  281 pop!
#      4 ./bitset.jl                  273 push!
#      1 ./bitset.jl                  273 push!(::Core.Compiler.BitSet, ::Int64)
#      4 ./bitset.jl                  273 push!
#      1 ./bitset.jl                  320 setdiff!
#      1 ./bitset.jl                  377 typeinf_local(::Core.Compiler.Infere...
#     10 ./boot.jl                    522 (::Core.GeneratedFunctionStub)(::Any...
#     33 ./boot.jl                    221 Type
#      1 ./boot.jl                    336 Type
#      1 ./boot.jl                    363 Type
#      2 ./boot.jl                    373 Type
#      5 ./boot.jl                    378 Type
#    756 ./boot.jl                    402 Type
#      3 ./boot.jl                    404 Type
#    235 ./boot.jl                    411 Type
#      3 ./boot.jl                    412 Type
#     30 ./boot.jl                    416 Type
#    149 ./boot.jl                    419 Type
#    179 ./boot.jl                    421 Type
#      2 ./boot.jl                    433 Type
#      1 ./boot.jl                    732 Type
#      3 ./boot.jl                    738 Type
#      5 ./boot.jl                    402 _collect
#      3 ./boot.jl                    597 check_top_bit
#      1 ./boot.jl                    603 checked_trunc_sint
#  13217 ./boot.jl                    328 eval
#      1 ./boot.jl                    402 getindex
#      1 ./boot.jl                    587 is_top_bit_set
#      6 ./boot.jl                    402 materialize
#      1 ./boot.jl                    404 materialize
#      1 ./boot.jl                    402 sort!
#      1 ./boot.jl                    642 toInt32
#      3 ./boot.jl                    708 toUInt64
#      2 ./broadcast.jl               544 _broadcast_getindex
#      2 ./broadcast.jl               550 _broadcast_getindex
#     41 ./broadcast.jl               551 _broadcast_getindex
#     41 ./broadcast.jl               578 _broadcast_getindex_evalf
#      2 ./broadcast.jl               574 _getindex
#      8 ./broadcast.jl               707 broadcast(::typeof(-), ::Array{Float...
#     24 ./broadcast.jl              1167 broadcasted(::Function, ::Base.Broad...
#     24 ./broadcast.jl              1169 broadcasted
#     48 ./broadcast.jl               773 copy
#      7 ./broadcast.jl               788 copy
#     74 ./broadcast.jl               791 copy
#     47 ./broadcast.jl               797 copyto!
#     47 ./broadcast.jl               842 copyto!
#      2 ./broadcast.jl               928 copyto_nonleaf!(::Array{Int64,1}, ::...
#      1 ./broadcast.jl               931 copyto_nonleaf!(::Array{Int64,1}, ::...
#     49 ./broadcast.jl               511 getindex
#     47 ./broadcast.jl               843 macro expansion
#     56 ./broadcast.jl               753 materialize
#      1 ./broadcast.jl               753 materialize(::Base.Broadcast.Broadca...
#      5 ./broadcast.jl               753 materialize
#      1 ./broadcast.jl               753 materialize(::Base.Broadcast.Broadca...
#     67 ./broadcast.jl               753 materialize
#      1 ./broadcast.jl               196 similar
#      2 ./cartesian.jl                64 macro expansion
#      1 ./char.jl                    135 Type
#      1 ./char.jl                    210 hash
#     16 ./char.jl                    229 print
#      2 ...stractinterpretation.jl   502 abstract_apply(::Any, ::Array{Any,1}...
#   3240 ...stractinterpretation.jl   519 abstract_apply(::Any, ::Array{Any,1}...
#      3 ...stractinterpretation.jl   566 abstract_call(::Any, ::Array{Any,1},...
#   3242 ...stractinterpretation.jl   567 abstract_call(::Any, ::Array{Any,1},...
#      2 ...stractinterpretation.jl   572 abstract_call(::Any, ::Array{Any,1},...
#      4 ...stractinterpretation.jl   577 abstract_call(::Any, ::Array{Any,1},...
#     47 ...stractinterpretation.jl   593 abstract_call(::Any, ::Tuple{}, ::Ar...
#      1 ...stractinterpretation.jl   594 abstract_call(::Any, ::Array{Any,1},...
#      2 ...stractinterpretation.jl   595 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   638 abstract_call(::Any, ::Array{Any,1},...
#      2 ...stractinterpretation.jl   643 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   699 abstract_call(::Any, ::Array{Any,1},...
#    501 ...stractinterpretation.jl   722 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   726 abstract_call(::Any, ::Array{Any,1},...
#      4 ...stractinterpretation.jl   733 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   756 abstract_call(::Any, ::Array{Any,1},...
#    134 ...stractinterpretation.jl   768 abstract_call(::Any, ::Array{Any,1},...
#    143 ...stractinterpretation.jl   769 abstract_call(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   772 abstract_call(::Any, ::Array{Any,1},...
#  53051 ...stractinterpretation.jl   776 abstract_call(::Any, ::Array{Any,1},...
#      2 ...stractinterpretation.jl    21 abstract_call_gf_by_type(::Any, ::Ar...
#     10 ...stractinterpretation.jl    37 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl    38 abstract_call_gf_by_type(::Any, ::Ar...
#      6 ...stractinterpretation.jl    39 abstract_call_gf_by_type(::Any, ::Ar...
#      3 ...stractinterpretation.jl    41 abstract_call_gf_by_type(::Any, ::Ar...
#      6 ...stractinterpretation.jl    44 abstract_call_gf_by_type(::Any, ::Ar...
#    504 ...stractinterpretation.jl    49 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl    56 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl    61 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    64 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    66 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    67 abstract_call_gf_by_type(::Any, ::Ar...
#  48999 ...stractinterpretation.jl    85 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl    87 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    90 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl    97 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl    98 abstract_call_gf_by_type(::Any, ::Ar...
#      2 ...stractinterpretation.jl   103 abstract_call_gf_by_type(::Any, ::Ar...
#   4013 ...stractinterpretation.jl   107 abstract_call_gf_by_type(::Any, ::Ar...
#      4 ...stractinterpretation.jl   108 abstract_call_gf_by_type(::Any, ::Ar...
#      6 ...stractinterpretation.jl   113 abstract_call_gf_by_type(::Any, ::Ar...
#      6 ...stractinterpretation.jl   124 abstract_call_gf_by_type(::Any, ::Ar...
#     30 ...stractinterpretation.jl   130 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl   138 abstract_call_gf_by_type(::Any, ::Ar...
#      1 ...stractinterpretation.jl   222 abstract_call_method(::Method, ::Any...
#      3 ...stractinterpretation.jl   227 abstract_call_method(::Method, ::Any...
#      1 ...stractinterpretation.jl   228 abstract_call_method(::Method, ::Any...
#      2 ...stractinterpretation.jl   275 abstract_call_method(::Method, ::Any...
#  48957 ...stractinterpretation.jl   345 abstract_call_method(::Method, ::Any...
#     32 ...stractinterpretation.jl   349 abstract_call_method(::Method, ::Any...
#      1 ...stractinterpretation.jl   146 abstract_call_method_with_const_args...
#      5 ...stractinterpretation.jl   152 abstract_call_method_with_const_args...
#      3 ...stractinterpretation.jl   153 abstract_call_method_with_const_args...
#      2 ...stractinterpretation.jl   155 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   162 abstract_call_method_with_const_args...
#      8 ...stractinterpretation.jl   165 abstract_call_method_with_const_args...
#     94 ...stractinterpretation.jl   191 abstract_call_method_with_const_args...
#     13 ...stractinterpretation.jl   193 abstract_call_method_with_const_args...
#     54 ...stractinterpretation.jl   194 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   195 abstract_call_method_with_const_args...
#      1 ...stractinterpretation.jl   196 abstract_call_method_with_const_args...
#   3819 ...stractinterpretation.jl   198 abstract_call_method_with_const_args...
#      8 ...stractinterpretation.jl   202 abstract_call_method_with_const_args...
#      4 ...stractinterpretation.jl   874 abstract_eval(::Any, ::Array{Any,1},...
#      2 ...stractinterpretation.jl   875 abstract_eval(::Any, ::Array{Any,1},...
#      8 ...stractinterpretation.jl   877 abstract_eval(::Any, ::Array{Any,1},...
#     13 ...stractinterpretation.jl   878 abstract_eval(::Any, ::Array{Any,1},...
#      2 ...stractinterpretation.jl   879 abstract_eval(::Any, ::Array{Any,1},...
#     26 ...stractinterpretation.jl   881 abstract_eval(::Any, ::Array{Any,1},...
#     49 ...stractinterpretation.jl   889 abstract_eval(::Any, ::Array{Any,1},...
#  53967 ...stractinterpretation.jl   890 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   892 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   921 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   924 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   935 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   980 abstract_eval(::Any, ::Array{Any,1},...
#      1 ...stractinterpretation.jl   782 abstract_eval_call(::Array{Any,1}, :...
#    560 ...stractinterpretation.jl   803 abstract_eval_call(::Array{Any,1}, :...
#  53402 ...stractinterpretation.jl   805 abstract_eval_call(::Array{Any,1}, :...
#     52 ...stractinterpretation.jl   989 abstract_eval_global
#     33 ...stractinterpretation.jl   990 abstract_eval_global
#      7 ...stractinterpretation.jl   996 abstract_eval_ssavalue(::Core.SSAVal...
#      9 ...stractinterpretation.jl    16 call_result_unused
#      2 ...stractinterpretation.jl   387 precise_container_type(::Any, ::Arra...
#      1 ...stractinterpretation.jl   391 precise_container_type(::Any, ::Arra...
#      1 ...stractinterpretation.jl   429 precise_container_type(::Any, ::Arra...
#      2 ...stractinterpretation.jl   535 pure_eval_call(::Any, ::Array{Any,1}...
#      5 ...stractinterpretation.jl   536 pure_eval_call(::Any, ::Array{Any,1}...
#      2 ...stractinterpretation.jl   537 pure_eval_call(::Any, ::Array{Any,1}...
#      2 ...stractinterpretation.jl   538 pure_eval_call(::Any, ::Array{Any,1}...
#      3 ...stractinterpretation.jl   542 pure_eval_call(::Any, ::Array{Any,1}...
#      7 ...stractinterpretation.jl   543 pure_eval_call(::Any, ::Array{Any,1}...
#     90 ...stractinterpretation.jl   544 pure_eval_call(::Any, ::Array{Any,1}...
#      3 ...stractinterpretation.jl   545 pure_eval_call(::Any, ::Array{Any,1}...
#     30 ...stractinterpretation.jl   557 pure_eval_call(::Any, ::Array{Any,1}...
#      1 ...stractinterpretation.jl   861 sparam_type
#      1 ...stractinterpretation.jl   867 sparam_type
#      2 ...stractinterpretation.jl   870 sparam_type
#      2 ...stractinterpretation.jl  1013 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1024 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1027 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1035 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1039 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1042 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1044 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1047 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1048 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1059 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1065 typeinf_local(::Core.Compiler.Infere...
#     14 ...stractinterpretation.jl  1077 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1083 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1085 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1105 typeinf_local(::Core.Compiler.Infere...
#   7840 ...stractinterpretation.jl  1121 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1123 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1124 typeinf_local(::Core.Compiler.Infere...
#  46196 ...stractinterpretation.jl  1135 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1137 typeinf_local(::Core.Compiler.Infere...
#     12 ...stractinterpretation.jl  1138 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1140 typeinf_local(::Core.Compiler.Infere...
#      5 ...stractinterpretation.jl  1159 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1162 typeinf_local(::Core.Compiler.Infere...
#      2 ...stractinterpretation.jl  1163 typeinf_local(::Core.Compiler.Infere...
#     14 ...stractinterpretation.jl  1164 typeinf_local(::Core.Compiler.Infere...
#      1 ...stractinterpretation.jl  1171 typeinf_local(::Core.Compiler.Infere...
#  54120 ...stractinterpretation.jl  1191 typeinf_nocycle(::Core.Compiler.Infe...
#      2 ...stractinterpretation.jl  1203 typeinf_nocycle(::Core.Compiler.Infe...
#     16 ...iler/inferenceresult.jl    12 Type
#     29 ...iler/inferenceresult.jl    17 Type
#      1 ...iler/inferenceresult.jl   152 cache_lookup(::Core.MethodInstance, ...
#      5 ...iler/inferenceresult.jl   153 cache_lookup(::Core.MethodInstance, ...
#      1 ...iler/inferenceresult.jl   156 cache_lookup(::Core.MethodInstance, ...
#     23 ...iler/inferenceresult.jl   158 cache_lookup(::Core.MethodInstance, ...
#      1 ...iler/inferenceresult.jl   166 cache_lookup(::Core.MethodInstance, ...
#    164 ...iler/inferenceresult.jl   171 cache_lookup(::Core.MethodInstance, ...
#      1 ...iler/inferenceresult.jl    25 is_argtype_match
#     12 ...iler/inferenceresult.jl    26 is_argtype_match
#      3 ...iler/inferenceresult.jl    39 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    40 matching_cache_argtypes(::Core.Metho...
#      8 ...iler/inferenceresult.jl    48 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    53 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    64 matching_cache_argtypes(::Core.Metho...
#     57 ...iler/inferenceresult.jl    65 matching_cache_argtypes(::Core.Metho...
#      8 ...iler/inferenceresult.jl    66 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl    70 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl    71 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl    92 matching_cache_argtypes(::Core.Metho...
#      2 ...iler/inferenceresult.jl   103 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl   113 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl   120 matching_cache_argtypes(::Core.Metho...
#      3 ...iler/inferenceresult.jl   129 matching_cache_argtypes(::Core.Metho...
#      5 ...iler/inferenceresult.jl   130 matching_cache_argtypes(::Core.Metho...
#      2 ...iler/inferenceresult.jl   131 matching_cache_argtypes(::Core.Metho...
#      1 ...iler/inferenceresult.jl   136 matching_cache_argtypes(::Core.Metho...
#      9 ...iler/inferenceresult.jl   144 matching_cache_argtypes(::Core.Metho...
#     14 ...piler/inferencestate.jl    51 Core.Compiler.InferenceState(::Core....
#      9 ...piler/inferencestate.jl    54 Core.Compiler.InferenceState(::Core....
#      3 ...piler/inferencestate.jl    57 Core.Compiler.InferenceState(::Core....
#      3 ...piler/inferencestate.jl    64 Core.Compiler.InferenceState(::Core....
#     22 ...piler/inferencestate.jl    73 Core.Compiler.InferenceState(::Core....
#     11 ...piler/inferencestate.jl    80 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl    81 Core.Compiler.InferenceState(::Core....
#      2 ...piler/inferencestate.jl    97 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl   110 Core.Compiler.InferenceState(::Core....
#    110 ...piler/inferencestate.jl   117 Core.Compiler.InferenceState(::Core....
#     67 ...piler/inferencestate.jl   120 Core.Compiler.InferenceState(::Core....
#      1 ...piler/inferencestate.jl   209 add_backedge!(::Core.MethodInstance,...
#      6 ...piler/inferencestate.jl   211 add_backedge!(::Core.MethodInstance,...
#      6 ...piler/inferencestate.jl   213 add_backedge!(::Core.MethodInstance,...
#      1 ...piler/inferencestate.jl   214 add_backedge!(::Core.MethodInstance,...
#      1 ...piler/inferencestate.jl   224 add_mt_backedge!(::Core.MethodTable,...
#      1 ...piler/inferencestate.jl   183 record_ssa_assign(::Int64, ::Any, ::...
#      7 ...piler/inferencestate.jl   185 record_ssa_assign(::Int64, ::Any, ::...
#      1 ...piler/inferencestate.jl   188 record_ssa_assign(::Int64, ::Any, ::...
#      2 ...piler/inferencestate.jl   193 record_ssa_assign(::Int64, ::Any, ::...
#      3 ...piler/inferencestate.jl   125 spvals_from_meth_instance(::Core.Met...
#      9 ...piler/inferencestate.jl   136 spvals_from_meth_instance(::Core.Met...
#      8 ...piler/inferencestate.jl   137 spvals_from_meth_instance(::Core.Met...
#      2 ...piler/inferencestate.jl   172 update_valid_age!
#      1 ...piler/inferencestate.jl   180 update_valid_age!
#      1 ./compiler/optimize.jl        20 Type
#      1 ./compiler/optimize.jl        22 Type
#      1 ./compiler/optimize.jl        23 Type
#      1 ./compiler/optimize.jl       114 add_backedge!
#      1 ./compiler/optimize.jl       115 add_backedge!
#      1 ./compiler/optimize.jl       116 add_backedge!
#     12 ./compiler/optimize.jl       366 inline_worthy
#      2 ./compiler/optimize.jl       124 isinlineable(::Method, ::Core.Compil...
#     12 ./compiler/optimize.jl       138 isinlineable(::Method, ::Core.Compil...
#   3518 ./compiler/optimize.jl       164 optimize(::Core.Compiler.Optimizatio...
#      1 ./compiler/optimize.jl       178 optimize(::Core.Compiler.Optimizatio...
#     38 ./compiler/optimize.jl       210 optimize(::Core.Compiler.Optimizatio...
#      1 ./compiler/optimize.jl       213 optimize(::Core.Compiler.Optimizatio...
#     19 ./compiler/optimize.jl       218 optimize(::Core.Compiler.Optimizatio...
#      7 ./compiler/optimize.jl       222 optimize(::Core.Compiler.Optimizatio...
#      3 ./compiler/optimize.jl       239 optimize(::Core.Compiler.Optimizatio...
#     14 ./compiler/optimize.jl       246 optimize(::Core.Compiler.Optimizatio...
#      7 ./compiler/optimize.jl       390 renumber_ir_elements!
#      2 ./compiler/optimize.jl       395 renumber_ir_elements!(::Array{Any,1}...
#      1 ./compiler/optimize.jl       406 renumber_ir_elements!(::Array{Any,1}...
#      1 ./compiler/optimize.jl       427 renumber_ir_elements!(::Array{Any,1}...
#      1 ./compiler/optimize.jl       272 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       273 statement_cost(::Expr, ::Int64, ::Co...
#      4 ./compiler/optimize.jl       277 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       295 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       299 statement_cost(::Expr, ::Int64, ::Co...
#      2 ./compiler/optimize.jl       304 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       308 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       314 statement_cost(::Expr, ::Int64, ::Co...
#      1 ./compiler/optimize.jl       104 update_valid_age!
#      1 ./compiler/optimize.jl       111 update_valid_age!
#      1 ./compiler/params.jl          57 Type
#     17 ...mpiler/ssair/domtree.jl    33 (::getfield(Core.Compiler, Symbol("#...
#     19 ...mpiler/ssair/domtree.jl   171 DFS(::Core.Compiler.CFG, ::UInt64)
#     62 ...mpiler/ssair/domtree.jl   175 DFS(::Core.Compiler.CFG, ::UInt64)
#      1 ...mpiler/ssair/domtree.jl   179 DFS(::Core.Compiler.CFG, ::UInt64)
#      3 ...mpiler/ssair/domtree.jl   183 DFS(::Core.Compiler.CFG, ::UInt64)
#     86 ...mpiler/ssair/domtree.jl   226 SNCA(::Core.Compiler.CFG)
#      5 ...mpiler/ssair/domtree.jl   232 SNCA(::Core.Compiler.CFG)
#      5 ...mpiler/ssair/domtree.jl   236 SNCA(::Core.Compiler.CFG)
#      1 ...mpiler/ssair/domtree.jl   260 SNCA(::Core.Compiler.CFG)
#      1 ...mpiler/ssair/domtree.jl   270 SNCA(::Core.Compiler.CFG)
#     11 ...mpiler/ssair/domtree.jl     4 Type
#      5 ...mpiler/ssair/domtree.jl     7 Type
#      3 ...mpiler/ssair/domtree.jl    10 Type
#      1 ...mpiler/ssair/domtree.jl   164 Type
#     98 ...mpiler/ssair/domtree.jl   104 construct_domtree(::Core.Compiler.CFG)
#     19 ...mpiler/ssair/domtree.jl   107 construct_domtree(::Core.Compiler.CFG)
#      4 ...mpiler/ssair/domtree.jl   110 construct_domtree(::Core.Compiler.CFG)
#      4 ...mpiler/ssair/domtree.jl   113 construct_domtree(::Core.Compiler.CFG)
#      3 ...mpiler/ssair/domtree.jl   114 construct_domtree(::Core.Compiler.CFG)
#      6 ...mpiler/ssair/domtree.jl   209 snca_compress!(::Array{Core.Compiler...
#      1 ...mpiler/ssair/domtree.jl   210 snca_compress!(::Array{Core.Compiler...
#      1 ...mpiler/ssair/domtree.jl    31 update_level!
#     17 ...mpiler/ssair/domtree.jl    32 update_level!(::Array{Core.Compiler....
#      3 ...mpiler/ssair/domtree.jl    32 update_level!
#      3 ./compiler/ssair/driver.jl    58 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    59 just_construct_ssa(::Core.CodeInfo, ...
#      3 ./compiler/ssair/driver.jl    60 just_construct_ssa(::Core.CodeInfo, ...
#      3 ./compiler/ssair/driver.jl    74 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    77 just_construct_ssa(::Core.CodeInfo, ...
#      3 ./compiler/ssair/driver.jl    78 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    92 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    94 just_construct_ssa(::Core.CodeInfo, ...
#      3 ./compiler/ssair/driver.jl   101 just_construct_ssa(::Core.CodeInfo, ...
#     17 ./compiler/ssair/driver.jl   102 just_construct_ssa(::Core.CodeInfo, ...
#     59 ./compiler/ssair/driver.jl   103 just_construct_ssa(::Core.CodeInfo, ...
#     83 ./compiler/ssair/driver.jl   104 just_construct_ssa(::Core.CodeInfo, ...
#      2 ./compiler/ssair/driver.jl   105 just_construct_ssa(::Core.CodeInfo, ...
#      2 ./compiler/ssair/driver.jl   106 just_construct_ssa(::Core.CodeInfo, ...
#      8 ./compiler/ssair/driver.jl   107 just_construct_ssa(::Core.CodeInfo, ...
#    526 ./compiler/ssair/driver.jl   109 just_construct_ssa(::Core.CodeInfo, ...
#      1 ./compiler/ssair/driver.jl    47 normalize
#    764 ./compiler/ssair/driver.jl   114 run_passes(::Core.CodeInfo, ::Int64,...
#     65 ./compiler/ssair/driver.jl   117 run_passes(::Core.CodeInfo, ::Int64,...
#   1989 ./compiler/ssair/driver.jl   118 run_passes(::Core.CodeInfo, ::Int64,...
#    117 ./compiler/ssair/driver.jl   120 run_passes(::Core.CodeInfo, ::Int64,...
#     45 ./compiler/ssair/driver.jl   122 run_passes(::Core.CodeInfo, ::Int64,...
#    317 ./compiler/ssair/driver.jl   123 run_passes(::Core.CodeInfo, ::Int64,...
#    119 ./compiler/ssair/driver.jl   126 run_passes(::Core.CodeInfo, ::Int64,...
#     17 ./compiler/ssair/driver.jl   128 run_passes(::Core.CodeInfo, ::Int64,...
#     83 ./compiler/ssair/driver.jl   129 run_passes(::Core.CodeInfo, ::Int64,...
#      1 ./compiler/ssair/driver.jl   131 run_passes(::Core.CodeInfo, ::Int64,...
#      1 ...piler/ssair/inlining.jl   161 (::getfield(Core.Compiler, Symbol("#...
#      1 ...piler/ssair/inlining.jl    10 Core.Compiler.InliningTodo(::Int64, ...
#      4 ...piler/ssair/inlining.jl    79 Core.Compiler.CFGInliningState(::Cor...
#     22 ...piler/ssair/inlining.jl   563 _spec_lambda
#      1 ...piler/ssair/inlining.jl   637 analyze_method!(::Int64, ::Any, ::An...
#      9 ...piler/ssair/inlining.jl   640 analyze_method!(::Int64, ::Any, ::An...
#      1 ...piler/ssair/inlining.jl   642 analyze_method!(::Int64, ::Any, ::An...
#     26 ...piler/ssair/inlining.jl   663 analyze_method!(::Int64, ::Any, ::An...
#      3 ...piler/ssair/inlining.jl   665 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   670 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   671 analyze_method!(::Int64, ::Any, ::An...
#    119 ...piler/ssair/inlining.jl   674 analyze_method!(::Int64, ::Any, ::An...
#      1 ...piler/ssair/inlining.jl   676 analyze_method!(::Int64, ::Any, ::An...
#     10 ...piler/ssair/inlining.jl   679 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   682 analyze_method!(::Int64, ::Any, ::An...
#     10 ...piler/ssair/inlining.jl   686 analyze_method!(::Int64, ::Any, ::An...
#      2 ...piler/ssair/inlining.jl   690 analyze_method!(::Int64, ::Any, ::An...
#     20 ...piler/ssair/inlining.jl   694 analyze_method!(::Int64, ::Any, ::An...
#     76 ...piler/ssair/inlining.jl   696 analyze_method!(::Int64, ::Any, ::An...
#    253 ...piler/ssair/inlining.jl   701 analyze_method!(::Int64, ::Any, ::An...
# ...
#      2 ...raph.jl/src/draw/svg.jl   365 drawwedge!(::SvgCanvas, ::MolecularG...
#      2 ...raph.jl/src/draw/svg.jl   375 drawwedge!(::SvgCanvas, ::MolecularG...
#      1 ...raph.jl/src/draw/svg.jl   379 drawwedge!(::SvgCanvas, ::MolecularG...
#      3 ...raph.jl/src/draw/svg.jl   384 drawwedge!(::SvgCanvas, ::MolecularG...
#      2 ...raph.jl/src/draw/svg.jl   385 drawwedge!(::SvgCanvas, ::MolecularG...
#    113 ...raph.jl/src/draw/svg.jl   138 initcanvas!(::SvgCanvas, ::VectorMol...
#     40 ...raph.jl/src/draw/svg.jl   139 initcanvas!(::SvgCanvas, ::VectorMol...
#    241 ...raph.jl/src/draw/svg.jl   141 initcanvas!(::SvgCanvas, ::VectorMol...
#      5 ...raph.jl/src/draw/svg.jl   145 initcanvas!(::SvgCanvas, ::VectorMol...
#      1 ...raph.jl/src/draw/svg.jl   146 initcanvas!(::SvgCanvas, ::VectorMol...
#      1 ...raph.jl/src/draw/svg.jl   218 ringdouble!(::SvgCanvas, ::Molecular...
#      3 ...raph.jl/src/draw/svg.jl   220 ringdouble!(::SvgCanvas, ::Molecular...
#     23 ...raph.jl/src/draw/svg.jl   221 ringdouble!(::SvgCanvas, ::Molecular...
#     17 ...raph.jl/src/draw/svg.jl   222 ringdouble!(::SvgCanvas, ::Molecular...
#    103 ...raph.jl/src/draw/svg.jl   296 setatomcenter!(::SvgCanvas, ::Array{...
#     32 ...raph.jl/src/draw/svg.jl   303 setatomleft!(::SvgCanvas, ::Array{Fl...
#     71 ...raph.jl/src/draw/svg.jl   289 setatomright!(::SvgCanvas, ::Array{F...
#   2205 ...raph.jl/src/draw/svg.jl   265 setbond!(::SvgCanvas, ::Int64, ::Int...
#    102 ...raph.jl/src/draw/svg.jl   165 singlebond!(::SvgCanvas, ::Molecular...
#    188 ...raph.jl/src/draw/svg.jl   166 singlebond!(::SvgCanvas, ::Molecular...
#      2 ...raph.jl/src/draw/svg.jl    63 tosvg(::SvgCanvas, ::Int64, ::Int64)
#      4 ...raph.jl/src/draw/svg.jl    65 tosvg(::SvgCanvas, ::Int64, ::Int64)
#      2 ...raph.jl/src/draw/svg.jl    76 tosvg(::SvgCanvas, ::Int64, ::Int64)
#      4 ...raph.jl/src/draw/svg.jl    80 tosvg(::SvgCanvas, ::Int64, ::Int64)
#      1 ...raph.jl/src/draw/svg.jl   154 trimbond
#    157 ...raph.jl/src/draw/svg.jl   156 trimbond
#     97 ...raph.jl/src/draw/svg.jl   158 trimbond
#      1 ...raph.jl/src/draw/svg.jl   187 wavesingle!(::SvgCanvas, ::Molecular...
#      3 ...raph.jl/src/draw/svg.jl   172 wedged!(::SvgCanvas, ::MolecularGrap...
#      8 ...raph.jl/src/draw/svg.jl   173 wedged!(::SvgCanvas, ::MolecularGrap...
#      1 ...rc/geometry/coords2d.jl    26 Type
#      3 ...rc/geometry/coords2d.jl   150 _midpoint(::MolecularGraph.Molecular...
#      1 ...rc/geometry/coords2d.jl   142 _translate(::MolecularGraph.Molecula...
#      1 ...rc/geometry/coords2d.jl   143 _translate(::MolecularGraph.Molecula...
#      1 ...rc/geometry/coords2d.jl   144 _translate(::MolecularGraph.Molecula...
#    157 ...rc/geometry/coords2d.jl   153 _trim_u(::MolecularGraph.MolecularGr...
#      1 ...rc/geometry/coords2d.jl   159 _trim_uv(::MolecularGraph.MolecularG...
#     97 ...rc/geometry/coords2d.jl   156 _trim_v(::MolecularGraph.MolecularGr...
#     23 ...rc/geometry/coords2d.jl   116 fmt
#    293 ...rc/geometry/coords2d.jl   119 fmt
#      1 ...rc/geometry/coords2d.jl   137 interiorangle(::MolecularGraph.Molec...
#    127 ...rc/geometry/coords2d.jl   177 isclockwise(::MolecularGraph.Molecul...
#     18 ...rc/geometry/coords2d.jl   179 isclockwise(::MolecularGraph.Molecul...
#      3 ...rc/geometry/coords2d.jl   180 isclockwise(::MolecularGraph.Molecul...
#    205 ...rc/geometry/coords2d.jl   182 isclockwise(::MolecularGraph.Molecul...
#      2 ...rc/geometry/coords2d.jl   183 isclockwise(::MolecularGraph.Molecul...
#      9 ...rc/geometry/coords2d.jl   151 midpoint
#      1 ...rc/geometry/coords2d.jl    82 point(::Float64, ::Float64)
#      1 ...rc/geometry/coords2d.jl    44 rawdata
#      4 ...rc/geometry/coords2d.jl    46 rawdata(::MolecularGraph.MolecularGr...
#      1 ...rc/geometry/coords2d.jl    84 segment
#      1 ...rc/geometry/coords2d.jl    85 segment
#     30 ...rc/geometry/coords2d.jl   166 transformmatrix(::MolecularGraph.Mol...
#     14 ...rc/geometry/coords2d.jl   167 transformmatrix(::MolecularGraph.Mol...
#     23 ...rc/geometry/coords2d.jl   168 transformmatrix(::MolecularGraph.Mol...
#      2 ...rc/geometry/coords2d.jl   147 translate
#    157 ...rc/geometry/coords2d.jl   154 trim_u(::MolecularGraph.MolecularGra...
#      2 ...rc/geometry/coords2d.jl   161 trim_uv
#     97 ...rc/geometry/coords2d.jl   157 trim_v(::MolecularGraph.MolecularGra...
#      9 ...c/graph/connectivity.jl    54 ##363
#     11 ...c/graph/connectivity.jl   151 ##366
#     20 ...c/graph/connectivity.jl   183 ##369(::MolecularGraph.MolecularGrap...
#     11 ...c/graph/connectivity.jl   184 ##369(::MolecularGraph.MolecularGrap...
#      1 ...c/graph/connectivity.jl    82 MolecularGraph.MolecularGraphModel.B...
#      8 ...c/graph/connectivity.jl    28 dfs!(::MolecularGraph.MolecularGraph...
#      1 ...c/graph/connectivity.jl    29 dfs!(::MolecularGraph.MolecularGraph...
#     29 ...c/graph/connectivity.jl    30 dfs!(::MolecularGraph.MolecularGraph...
#      1 ...c/graph/connectivity.jl    88 dfs!(::MolecularGraph.MolecularGraph...
#      1 ...c/graph/connectivity.jl    89 dfs!(::MolecularGraph.MolecularGraph...
#      2 ...c/graph/connectivity.jl    90 dfs!(::MolecularGraph.MolecularGraph...
#      2 ...c/graph/connectivity.jl    91 dfs!(::MolecularGraph.MolecularGraph...
#      2 ...c/graph/connectivity.jl    95 dfs!(::MolecularGraph.MolecularGraph...
#    111 ...c/graph/connectivity.jl    97 dfs!(::MolecularGraph.MolecularGraph...
#      1 ...c/graph/connectivity.jl   101 dfs!(::MolecularGraph.MolecularGraph...
#      1 ...c/graph/connectivity.jl   110 dfs!(::MolecularGraph.MolecularGraph...
#      1 ...c/graph/connectivity.jl   118 findbiconnected(::MolecularGraph.Mol...
#     10 ...c/graph/connectivity.jl   121 findbiconnected(::MolecularGraph.Mol...
#      9 ...c/graph/connectivity.jl    38 run!(::MolecularGraph.MolecularGraph...
#     34 ...h.jl/src/graph/cycle.jl    41 ##371(::MolecularGraph.MolecularGrap...
#     25 ...h.jl/src/graph/cycle.jl    42 ##371(::MolecularGraph.MolecularGrap...
#   1072 ...h.jl/src/graph/cycle.jl    43 ##371(::MolecularGraph.MolecularGrap...
#      4 ...h.jl/src/graph/cycle.jl    44 ##371(::MolecularGraph.MolecularGrap...
#      9 ...h.jl/src/graph/cycle.jl    16 find_cotree_edge(::MolecularGraph.Mo...
#      9 ...h.jl/src/graph/cycle.jl    98 findmincycle(::MolecularGraph.Molecu...
#     16 ...h.jl/src/graph/cycle.jl    99 findmincycle(::MolecularGraph.Molecu...
#      1 ...h.jl/src/graph/cycle.jl   103 findmincycle(::MolecularGraph.Molecu...
#      1 ...h.jl/src/graph/cycle.jl   104 findmincycle(::MolecularGraph.Molecu...
#      3 ...h.jl/src/graph/cycle.jl   106 findmincycle(::MolecularGraph.Molecu...
#      2 ...h.jl/src/graph/cycle.jl   107 findmincycle(::MolecularGraph.Molecu...
#     94 ...h.jl/src/graph/cycle.jl   112 findmincycle(::MolecularGraph.Molecu...
#      1 ...h.jl/src/graph/cycle.jl   114 findmincycle(::MolecularGraph.Molecu...
#      4 ...h.jl/src/graph/cycle.jl   116 findmincycle(::MolecularGraph.Molecu...
#     18 ...h.jl/src/graph/cycle.jl   117 findmincycle(::MolecularGraph.Molecu...
#     43 ...h.jl/src/graph/cycle.jl   118 findmincycle(::MolecularGraph.Molecu...
#      3 ...h.jl/src/graph/cycle.jl   119 findmincycle(::MolecularGraph.Molecu...
#     44 ...h.jl/src/graph/cycle.jl   120 findmincycle(::MolecularGraph.Molecu...
#      2 ...h.jl/src/graph/cycle.jl    28 mincyclebasis(::MolecularGraph.Molec...
#   1035 ...h.jl/src/graph/cycle.jl    85 mincyclebasis(::MolecularGraph.Molec...
#      4 ...h.jl/src/graph/cycle.jl    86 mincyclebasis(::MolecularGraph.Molec...
#     10 ...h.jl/src/graph/cycle.jl    88 mincyclebasis(::MolecularGraph.Molec...
#     21 ...h.jl/src/graph/cycle.jl    89 mincyclebasis(::MolecularGraph.Molec...
#     73 .../src/graph/graphutil.jl    18 adjacencies
#      1 .../src/graph/graphutil.jl    18 adjacencies(::VectorMol{SDFileAtom,S...
#      2 .../src/graph/graphutil.jl    18 adjacencies
#      1 .../src/graph/graphutil.jl    26 incidences
#      2 .../src/graph/interface.jl   288 apparentvalence(::VectorMol{SDFileAt...
#     40 .../src/graph/interface.jl   288 atomsymbol(::VectorMol{SDFileAtom,SD...
#      1 .../src/graph/interface.jl   278 bondorder(::VectorMol{SDFileAtom,SDF...
#      1 .../src/graph/interface.jl   282 bondorder(::VectorMol{SDFileAtom,SDF...
#      2 .../src/graph/interface.jl   283 bondorder(::VectorMol{SDFileAtom,SDF...
#      1 .../src/graph/interface.jl   285 bondorder(::VectorMol{SDFileAtom,SDF...
#     26 .../src/graph/interface.jl   288 bondorder(::VectorMol{SDFileAtom,SDF...
#      1 .../src/graph/interface.jl   282 bridges(::MolecularGraph.MolecularGr...
#     11 .../src/graph/interface.jl   288 bridges(::MolecularGraph.MolecularGr...
#     28 .../src/graph/interface.jl   288 charge(::VectorMol{SDFileAtom,SDFile...
#      9 .../src/graph/interface.jl   280 connected_components
#      1 .../src/graph/interface.jl   282 coords2d(::VectorMol{SDFileAtom,SDFi...
#      2 .../src/graph/interface.jl   283 coords2d(::VectorMol{SDFileAtom,SDFi...
#     55 .../src/graph/interface.jl   288 coords2d(::VectorMol{SDFileAtom,SDFi...
#    136 .../src/graph/interface.jl   288 implicithcount(::VectorMol{SDFileAto...
#   1135 .../src/graph/interface.jl   288 mincycles(::MolecularGraph.Molecular...
#      1 .../src/graph/interface.jl   289 mincycles(::MolecularGraph.Molecular...
#     27 .../src/graph/interface.jl   288 nodedegree(::VectorMol{SDFileAtom,SD...
#     31 .../src/graph/interface.jl   288 two_edge_connected(::MolecularGraph....
#     56 .../src/graph/interface.jl   288 valence(::VectorMol{SDFileAtom,SDFil...
#      6 ...h.jl/src/graph/merge.jl    11 shallowmerge(::MolecularGraph.Molecu...
#      2 ...h.jl/src/graph/merge.jl    14 shallowmerge(::MolecularGraph.Molecu...
#      1 ...h.jl/src/graph/merge.jl    22 shallowmerge(::MolecularGraph.Molecu...
#      2 ...h.jl/src/graph/merge.jl    24 shallowmerge(::MolecularGraph.Molecu...
#      4 ...h.jl/src/graph/merge.jl    27 shallowmerge(::MolecularGraph.Molecu...
#      1 ...h.jl/src/graph/merge.jl    33 shallowmerge(::MolecularGraph.Molecu...
#      1 ...c/graph/shortestpath.jl    25 shortestpath(::MolecularGraph.Molecu...
#     68 ...c/graph/shortestpath.jl    26 shortestpath(::MolecularGraph.Molecu...
#      2 ...c/graph/shortestpath.jl    32 shortestpath(::MolecularGraph.Molecu...
#      1 ...c/graph/shortestpath.jl    33 shortestpath(::MolecularGraph.Molecu...
#      5 ...c/graph/shortestpath.jl    36 shortestpath(::MolecularGraph.Molecu...
#      9 ...c/graph/shortestpath.jl    38 shortestpath(::MolecularGraph.Molecu...
#      8 ...c/graph/shortestpath.jl    39 shortestpath(::MolecularGraph.Molecu...
#      1 ....jl/src/graph/ugraph.jl    26 MolecularGraph.MolecularGraphModel.V...
#      1 ....jl/src/graph/ugraph.jl   126 edgeset
#      9 ....jl/src/graph/ugraph.jl   224 mapgraph(::MolecularGraph.MolecularG...
#      2 ....jl/src/graph/ugraph.jl   227 mapgraph(::MolecularGraph.MolecularG...
#      2 ....jl/src/graph/ugraph.jl   229 mapgraph(::MolecularGraph.MolecularG...
#      3 ....jl/src/graph/ugraph.jl   117 neighbors
#      5 ....jl/src/graph/ugraph.jl   240 nodeset
#      5 ....jl/src/graph/ugraph.jl   259 updateedge!(::MolecularGraph.Molecul...
#      1 ....jl/src/graph/ugraph.jl    53 vectorgraph
#      1 ...view/inducedsubgraph.jl    52 _nodesubgraph
#      1 ...view/inducedsubgraph.jl    54 _nodesubgraph
#      1 ...view/inducedsubgraph.jl   117 collect(::Base.Generator{UnitRange{I...
#      1 ...view/inducedsubgraph.jl    69 edgesubgraph(::MolecularGraph.Molecu...
#      2 ...view/inducedsubgraph.jl    72 edgesubgraph(::MolecularGraph.Molecu...
#      2 ...view/inducedsubgraph.jl   117 find_cotree_edge(::MolecularGraph.Mo...
#      1 ...view/inducedsubgraph.jl   105 mapgraph(::MolecularGraph.MolecularG...
#      5 ...view/inducedsubgraph.jl   117 neighbors
#      1 ...view/inducedsubgraph.jl   111 nodeset
#      2 ...view/inducedsubgraph.jl    43 nodesubgraph(::MolecularGraph.Molecu...
#      1 ...ph.jl/src/model/bond.jl    35 setnodes
#      2 ...l/src/model/molgraph.jl    21 Type
#      3 ...l/src/model/molgraph.jl    25 VectorMol{SDFileAtom,SDFileBond}()
#    804 ...l/src/model/molgraph.jl   147 getindex(::VectorMol{SDFileAtom,SDFi...
#      3 ...l/src/model/molgraph.jl    41 vectormol(::Array{SDFileAtom,1}, ::A...
#      5 ...l/src/model/molgraph.jl    44 vectormol(::Array{SDFileAtom,1}, ::A...
#     25 ...ph.jl/src/properties.jl    57 ##374(::VectorMol{SDFileAtom,SDFileB...
#     28 ...ph.jl/src/properties.jl    66 ##375(::VectorMol{SDFileAtom,SDFileB...
#     26 ...ph.jl/src/properties.jl    85 ##377(::VectorMol{SDFileAtom,SDFileB...
#     27 ...ph.jl/src/properties.jl    94 ##378
#      1 ...ph.jl/src/properties.jl   107 ##379(::VectorMol{SDFileAtom,SDFileB...
#      1 ...ph.jl/src/properties.jl   108 ##379(::VectorMol{SDFileAtom,SDFileB...
#      1 ...ph.jl/src/properties.jl   125 ##380(::VectorMol{SDFileAtom,SDFileB...
#     17 ...ph.jl/src/properties.jl   131 ##380(::VectorMol{SDFileAtom,SDFileB...
#     16 ...ph.jl/src/properties.jl   132 ##380(::VectorMol{SDFileAtom,SDFileB...
#     22 ...ph.jl/src/properties.jl   134 ##380(::VectorMol{SDFileAtom,SDFileB...
#    136 ...ph.jl/src/properties.jl   187 ##383(::VectorMol{SDFileAtom,SDFileB...
#   1136 ...ph.jl/src/properties.jl    25 sssr
#   1400 ....jl/src/sdfilereader.jl    65 iterate
#      2 ....jl/src/sdfilereader.jl    66 iterate(::SDFileReader, ::Nothing)
#      2 ....jl/src/sdfilereader.jl    68 iterate(::SDFileReader, ::Nothing)
#      2 ....jl/src/sdfilereader.jl    69 iterate(::SDFileReader, ::Nothing)
#   1447 ....jl/src/sdfilereader.jl    70 iterate(::SDFileReader, ::Nothing)
#      6 ....jl/src/sdfilereader.jl    72 iterate(::SDFileReader, ::Nothing)
#      2 ....jl/src/sdfilereader.jl    73 iterate(::SDFileReader, ::Nothing)
#    195 ....jl/src/sdfilereader.jl    87 nohaltsupplier(::Array{String,1})
#      4 ....jl/src/sdfilereader.jl   128 parse(::Type{VectorMol{SDFileAtom,SD...
#    168 ....jl/src/sdfilereader.jl   132 parse(::Type{VectorMol{SDFileAtom,SD...
#     23 ....jl/src/sdfilereader.jl   133 parse(::Type{VectorMol{SDFileAtom,SD...
#      2 ....jl/src/sdfilereader.jl   162 sdfatom(::String)
#      1 ....jl/src/sdfilereader.jl   163 sdfatom(::String)
#      2 ....jl/src/sdfilereader.jl   164 sdfatom(::String)
#      1 ....jl/src/sdfilereader.jl   166 sdfatom(::String)
#     18 ....jl/src/sdfilereader.jl   173 sdfatom(::String)
#      2 ....jl/src/sdfilereader.jl   181 sdfbond(::String)
#    120 ....jl/src/sdfilereader.jl   140 sdfmol(::SubArray{String,1,Array{Str...
#     25 ....jl/src/sdfilereader.jl   145 sdfmol(::SubArray{String,1,Array{Str...
#      2 ....jl/src/sdfilereader.jl   147 sdfmol(::SubArray{String,1,Array{Str...
#      8 ....jl/src/sdfilereader.jl   150 sdfmol(::SubArray{String,1,Array{Str...
#      5 ....jl/src/sdfilereader.jl   151 sdfmol(::SubArray{String,1,Array{Str...
#      8 ....jl/src/sdfilereader.jl   152 sdfmol(::SubArray{String,1,Array{Str...
#      2 ....jl/src/sdfilereader.jl   222 sdfoptions(::SubArray{String,1,Array...
#      8 ....jl/src/sdfilereader.jl   224 sdfoptions(::SubArray{String,1,Array...
